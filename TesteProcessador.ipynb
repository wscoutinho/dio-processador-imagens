# %%
from processador_imagens_wsc.util import io, plot
from processador_imagens_wsc.processador import combinacao, transformacao

# %%
imagem1 = io.ler_imagem("img-old-man-1280.jpg")
imagem2 = io.ler_imagem("img-river-1280.jpg")

# %%
plot.plot_imagem(imagem1)
plot.plot_imagem(imagem2)

# %%
imagem_correspondente = combinacao.transferir_histograma_dupla(imagem1, imagem2)
plot.plot_imagem(imagem_correspondente)
